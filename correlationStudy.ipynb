# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('dataSudan.csv')

# %%
df.shape
# Out:
# (27, 7)

# %%
df.drop(['timeStamp'], axis=1, inplace=True)

# %%
df.head()
# Out:
#        Sales  numNewRecruit  numActiveDistributors  avgOrderValue    EMultiF  \
# 0  605796.31           2548                   4168          391.2  1630521.6
# 1  487740.04           2343                   3275          289.9   949422.5
# 2  532938.29           3133                   3451          295.0  1018045.0
# 3  359743.51           2763                   3114          273.6   851990.4
# 4  300941.80           2763                   2837          265.1   752088.7
#
#     prmExp
# 0  16000.0
# 1  20000.0
# 2  27800.0
# 3      0.0
# 4  54842.1

# %%
sns_plot = sns.pairplot(df)
sns_plot.savefig("SudanPlot.png")

# %%
import numpy as np
from sklearn.decomposition import PCA

# %%
df.info()

# %%
df_np = df.to_numpy()

# %%
pca = PCA(n_components=2)
pca.fit(df_np)

# %%
X_reduced = PCA(n_components=2).fit_transform(df_np)
plt.scatter(X_reduced[:, 0], X_reduced[:, 1])

# %%
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score
